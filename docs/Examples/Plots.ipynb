# %% [markdown]
# The **spiral_frequencies** and **cloud_frequencies** methods utilize the [**Spiral**](/ScanPyImports/Api/plotter/#ScanPyImports.plotter.Spiral) and [**Cloud**](/ScanPyImports/Api/plotter/#ScanPyImports.plotter.Cloud) classes, respectively. You can use these classes to plot any data.
#
# As an example, let's use data on the **most-spoken first languages** from the [CIA World Factbook](https://www.cia.gov/the-world-factbook/countries/world/#people-and-society).

# %%
data = {'Mandarin Chinese': 12.3, 'Spanish': 6.0, 'English': 5.1, 'Arabic': 5.1, 'Hindi': 3.5, 'Bengali': 3.3, 'Portuguese': 3.0, 'Russian': 2.1, 'Japanese': 1.7, 'Punjabi Western': 1.3, 'Javanese': 1.1}

# %% [markdown]
# ## Spiral

# %% [markdown]
# To create a spiral plot, use the [plot](/ScanPyImports/Api/plotter/#ScanPyImports.plotter.Spiral.plot) method.

# %%
from ScanPyImports.plotter import Spiral

spiral=Spiral() 
# Prepare the data 
# = > Sort by ascending order
data = dict(sorted(data.items(), key=lambda item: item[1]))
labels = data.keys()
values = data.values()

fig, ax, bars, texts = spiral.plot(labels,values)

# %% [markdown]
# ## Cloud

# %% [markdown]
# To create a cloud plot, use the [plot](/ScanPyImports/Api/plotter/#ScanPyImports.plotter.Cloud.plot) method.

# %%
from ScanPyImports.plotter import Cloud 
cloud = Cloud()
fig, ax, wc, im = cloud.plot(data)
